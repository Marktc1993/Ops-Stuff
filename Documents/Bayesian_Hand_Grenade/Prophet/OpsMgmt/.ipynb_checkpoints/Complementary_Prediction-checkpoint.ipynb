# %%
from fbprophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel("Plot of utilization of station 1, averaged over each day.xls")
# Out:
# ---------------------------------------------------------------------------
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-4-5107f7467cf0> in <module>()
# ----> 1 df = pd.read_excel("Plot of utilization of station 1, averaged over each day.xls")
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in read_excel(io, sheetname, header, skiprows, skip_footer, index_col, names, parse_cols, parse_dates, date_parser, na_values, thousands, convert_float, has_index_names, converters, dtype, true_values, false_values, engine, squeeze, **kwds)
#     201
#     202     if not isinstance(io, ExcelFile):
# --> 203         io = ExcelFile(io, engine=engine)
#     204
#     205     return io._parse_excel(
#
# ~\Anaconda3\lib\site-packages\pandas\io\excel.py in __init__(self, io, **kwds)
#     258             self.book = xlrd.open_workbook(file_contents=data)
#     259         elif isinstance(io, compat.string_types):
# ...

# %%
df['y'] = df['data']
df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-73513f3d76f9> in <module>()
# ----> 1 df['y'] = df['data']
#       2 df['ds'] = pd.to_datetime(df['days'], unit = 'd')
#
# NameError: name 'df' is not defined

# %%
# m = Prophet()
# m.fit(df);

# %%
# # Python
# m.plot(forecast);

# %% [markdown]
# # Plot of utilization of station 1, averaged over each day

# %%
# # Python
# m.plot_components(forecast);

# %%
# df = pd.read_excel("Plot of number of jobs accepted each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality=True)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # JOB PLOT FORECASTED 25 days!
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # Plot of number of jobs accepted each day 25 days!

# %%
# df = pd.read_excel("Plot of inventory level in kits (not an average).xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality=True)
# m.fit(df.loc[48:,:]);
# future = m.make_future_dataframe(periods=50)
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Plot of inventory level in kits (not an average) FORECASTED 25 days from most recent spike!
# # Python
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:fbprophet.forecaster:n_changepoints greater than number of observations.Using 2.0.

# %% [markdown]
# # Plot of inventory level in kits (not an average) FORECASTED 25 days from most recent spike, this plot is really useless so don't stare too long!

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 1.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality=True)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!
# # Python
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 2.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality=True)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Python
# m.plot_components(forecast);

# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # Plot of daily average number of kits queued for station 2

# %%
# df = pd.read_excel("Plot of utilization of station 3, averaged over each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')

# df['cap'] = 10000
# df['floor'] = 0

# m = Prophet(growth = 'linear')
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0 
# future['cap'] = 1
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Python
# m.plot_components(forecast);

# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of utilization of station 3, averaged over each day.

# %%
# df = pd.read_excel("Plot of utilization of station 2, averaged over each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')

# df['cap'] = 1
# df['floor'] = 0

# m = Prophet(growth = 'linear')
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0 
# future['cap'] = 1
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Python
# m.plot_components(forecast);

# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of utilization of station 2, averaged over each day

# %%
# df = pd.read_excel("Plot of number of completed jobs each day.xlsx")
# df['y'] = df['contract 1']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')

# df['cap'] = 1
# df['floor'] = 0

# m = Prophet(growth = 'linear')
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0 
# # future['cap'] = 10
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# # Python
# m.plot_components(forecast);

# # Plot of daily average number of kits queued for station 1 FORECASTED 25 days!
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of number of completed jobs each day
