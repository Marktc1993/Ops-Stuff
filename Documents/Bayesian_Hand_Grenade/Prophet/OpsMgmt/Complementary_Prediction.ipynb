# %% [markdown]
# ## Complementary Analysis
# Hey guys I used a free software library called Prophet made by the Data Science team at Facebook. I used this earlier this year in a research project, it may not be as applicable in this assignment but feel free to use this is purchasing decisions for the Littlefield project, or not haha.

# %%
# from fbprophet import Prophet
# import pandas as pd
# import matplotlib.pyplot as plt
# %matplotlib inline
# import os

# %%
# os.getcwd()
# Out:
# 'C:\\Users\\markt\\Documents\\Bayesian_Hand_Grenade\\Prophet\\OpsMgmt'

# %%
# df = pd.read_excel("Plot of utilization of station 1, averaged over each day.xlsx")

# %%
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')

# %%
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
# df = pd.read_excel("Plot of utilization of station 1, averaged over each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(growth='logistic')
# df['cap'] = 1
# df['floor'] = 0
# m.fit(df);
# future = m.make_future_dataframe(periods=50)
# future['floor'] = 0 
# future['cap'] = 1
# future.tail()

# # Python
# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# # Python
# m.plot(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of utilization of station 1, averaged over each day

# %%
# # Python
m.plot_components(forecast);

# %%
# df = pd.read_excel("Plot of number of jobs accepted each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(changepoint_prior_scale=0.5,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.99)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
#  ## ^^ Plot of number of jobs accepted each day

# %%
# df = pd.read_excel("Plot of daily average job lead time.xlsx")
# df['y'] = df['contract 1']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(changepoint_prior_scale=0.5,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of number of jobs lead time!

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 1.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(changepoint_prior_scale=0.5,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=50)
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of inventory level in kits (not an average) FORECASTED 25 days from most recent spike, this plot is really useless so don't stare too long!

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 2.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.40)
# m.fit(df);
# # future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # ^^^^Plot of daily average number of kits queued for station 2 FORECASTED 25 days!

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 1.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality= True, changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # Plot of daily average number of kits queued for station 1

# %%
# df = pd.read_excel("Plot of daily average number of kits queued for station 3.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# df['cap'] = 20
# df['floor'] = 0

# m=Prophet(growth='logistic')
# # m = Prophet(daily_seasonality= True, changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=50)
# future['floor'] = 0
# future['cap'] = 8


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# # Plot of daily average number of kits queued for station 3

# %%
# df = pd.read_excel("Plot of daily average revenue per job.xlsx")
# df['y'] = df['contract 1']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality= True, changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # ^^^ Plot of daily average revenue per job

# %%
# df = pd.read_excel("Plot of number of completed jobs each day.xlsx")
# df['y'] = df['contract 1']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality= True, changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# # ^^^ Plot of number of completed jobs each day

# %%
# df = pd.read_excel("Plot of utilization of station 2, averaged over each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(daily_seasonality= True, changepoint_prior_scale=0.05,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.

# %% [markdown]
# ##  ^ ^ ^ Plot of utilization of station 2, averaged over each day

# %%
# df = pd.read_excel("Plot of utilization of station 3, averaged over each day.xlsx")
# df['y'] = df['data']
# df['ds'] = pd.to_datetime(df['days'], unit = 'd')
# m = Prophet(changepoint_prior_scale=0.1,n_changepoints=50,mcmc_samples=300, uncertainty_samples=1000, interval_width = 0.95)
# m.fit(df);
# future = m.make_future_dataframe(periods=25)
# future['floor'] = 0
# future.tail()


# forecast = m.predict(future)
# forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# m.plot(forecast);
# # # JOB PLOT FORECASTED 25 days!
# m.plot_components(forecast);
# Out:
# INFO:fbprophet.forecaster:Disabling yearly seasonality. Run prophet with yearly_seasonality=True to override this.
# INFO:fbprophet.forecaster:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %% [markdown]
# ## ^^^ Plot of utilization of station 3, averaged over each day.xls
